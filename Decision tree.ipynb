# %% [markdown]
# # LetsGrowMore - LGM Virtual Internship Program 2021
#
# NAME :S.keerthana Sri
#
# DATA ANALYTICS INTERNSHIP
#
# TASK-2: INTERMEDIATE LEVEL : PREDICTION USING DECISION TREE

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn import tree
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv("C:\\Users\\WELCOME\\Downloads\\Iris (1).csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data=data.iloc[:,1:6]
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
data.shape
# Out:
# (150, 5)

# %%
data["Species"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# Data visualization

# %%
data["SepalLengthCm"].hist()
# Out:
# <AxesSubplot:>

# %%
data["SepalWidthCm"].hist()
# Out:
# <AxesSubplot:>

# %%
data["PetalLengthCm"].hist()
# Out:
# <AxesSubplot:>

# %%
data["PetalWidthCm"].hist()
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis("equal")
l=["versicolor","virginica","setosa"]
s=[50,50,50]
ax.pie(s, labels= l,autopct="%1.2f%%")
plt.show()

# %%
colors=["red","green","blue"]
species=["Iris-versicolor","Iris-virginica","Iris-setosa"]

# %%
for i in range(3):
    x=data[data["Species"] == species[i]]
    plt.scatter(x["SepalLengthCm"],x["SepalWidthCm"], c= colors[i], label=species[i])
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               
plt.legend()

# %%
for i in range(3):
    x=data[data["Species"] == species[i]]
    plt.scatter(x["PetalLengthCm"],x["PetalWidthCm"], c= colors[i], label=species[i])
plt.xlabel("Petal length")
plt.ylabel("Petal width")
plt.legend()

# %%
import matplotlib.pyplot as plt
plt.figure(1)
plt.boxplot([data["SepalLengthCm"]])
plt.figure(2)
plt.boxplot([data["SepalWidthCm"]])
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x="Species",y="PetalLengthCm",data=data)
plt.subplot(2,2,2)
sns.violinplot(x="Species",y="PetalWidthCm",data=data)
plt.subplot(2,2,3)
sns.violinplot(x="Species",y="PetalWidthCm",data=data)
plt.subplot(2,2,4)
sns.violinplot(x="Species",y="PetalWidthCm",data=data)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %%
sns.pairplot(data,hue="Species")

# %%
data.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.heatmap(data.corr());

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
data["Species"]=le.fit_transform(data["Species"])
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# Performing train-test split

# %%
from sklearn.model_selection import train_test_split
x=data.iloc[:,0:4]
y=data["Species"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
dt=DecisionTreeClassifier()
dt=dt.fit(x_train,y_train)

# %%
dt
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
y_pred
# Out:
# array([2, 2, 2, 0, 0, 0, 2, 0, 0, 1, 1, 1, 1, 2, 1, 1, 2, 1, 0, 1, 0, 0,
#        2, 2, 1, 0, 2, 2, 0, 0, 1, 2, 1, 0, 1, 2, 2, 0, 2, 0, 2, 0, 0, 1,
#        2])

# %%
y_test
# Out:
# 125    2
# 131    2
# 114    2
# 18     0
# 44     0
# 42     0
# 126    2
# 12     0
# 21     0
# 52     1
# 60     1
# 51     1
# 57     1
# 123    2
# 92     1
# 99     1
# 149    2
# 64     1
# 22     0
# 86     1
# 5      0
# 27     0
# 101    2
# 148    2
# 134    2
# 16     0
# 116    2
# 144    2
# 49     0
# 36     0
# 85     1
# 77     1
# 89     1
# 20     0
# 53     1
# 120    2
# 145    2
# 38     0
# 139    2
# 9      0
# 147    2
# 47     0
# 33     0
# 73     1
# 141    2
# Name: Species, dtype: int32

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
cm = confusion_matrix(y_test, y_pred)
print(cm)
print("\n",accuracy_score(y_test, y_pred))
print("\n",classification_report(y_test,y_pred))
# Out:
# [[16  0  0]
#  [ 0 12  1]
#  [ 0  1 15]]
#
#  0.9555555555555556
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.92      0.92      0.92        13
#            2       0.94      0.94      0.94        16
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
names=["Sepal length","Sepal width","Petal length","Petal width"]
species=["Setosa","Versicolor","Verginica"]

# %%
plot_tree(dt,feature_names=names,class_names=species,filled=True)
# Out:
# [Text(133.92000000000002, 199.32, 'Petal length <= 2.45\ngini = 0.666\nsamples = 105\nvalue = [34, 37, 34]\nclass = Versicolor'),
#  Text(100.44000000000001, 163.07999999999998, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]\nclass = Setosa'),
#  Text(167.40000000000003, 163.07999999999998, 'Petal width <= 1.65\ngini = 0.499\nsamples = 71\nvalue = [0, 37, 34]\nclass = Versicolor'),
#  Text(66.96000000000001, 126.83999999999999, 'Petal length <= 4.95\ngini = 0.142\nsamples = 39\nvalue = [0, 36, 3]\nclass = Versicolor'),
#  Text(33.480000000000004, 90.6, 'gini = 0.0\nsamples = 35\nvalue = [0, 35, 0]\nclass = Versicolor'),
#  Text(100.44000000000001, 90.6, 'Sepal length <= 6.15\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]\nclass = Verginica'),
#  Text(66.96000000000001, 54.359999999999985, 'Petal length <= 5.05\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = Versicolor'),
# ...

# %%
model=DecisionTreeClassifier().fit(x,y)

# %%
plt.figure(figsize=(20,15))
tree=tree.plot_tree(model,feature_names=names,class_names=species,filled=True)
